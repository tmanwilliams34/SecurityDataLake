# %%
import pandas as pd
import os
from glob import glob

# %% [markdown]
# Just to double check all columns match together properly. 02-20-2018 has extra rows that need to be taken account of.

# %%
for file in glob("../analytics/*.parquet"):
    df = pd.read_parquet(file)

    print(file)
    print(df.columns.tolist())
    print()
# Out:
# ../analytics/03-01-2018-analytics.parquet
# ['Timestamp', 'Dst Port', 'Protocol', 'Flow Duration', 'Flow Byts/s', 'Flow Pkts/s', 'Tot Fwd Pkts', 'Tot Bwd Pkts', 'Label']
#
# ../analytics/02-23-2018-analytics.parquet
# ['Timestamp', 'Dst Port', 'Protocol', 'Flow Duration', 'Flow Byts/s', 'Flow Pkts/s', 'Tot Fwd Pkts', 'Tot Bwd Pkts', 'Label']
#
# ../analytics/02-16-2018-analytics.parquet
# ['Timestamp', 'Dst Port', 'Protocol', 'Flow Duration', 'Flow Byts/s', 'Flow Pkts/s', 'Tot Fwd Pkts', 'Tot Bwd Pkts', 'Label']
#
# ../analytics/02-15-2018-analytics.parquet
# ['Timestamp', 'Dst Port', 'Protocol', 'Flow Duration', 'Flow Byts/s', 'Flow Pkts/s', 'Tot Fwd Pkts', 'Tot Bwd Pkts', 'Label']
#
# ../analytics/02-20-2018-analytics.parquet
# ['Timestamp', 'Dst Port', 'Protocol', 'Flow Duration', 'Flow Byts/s', 'Flow Pkts/s', 'Tot Fwd Pkts', 'Tot Bwd Pkts', 'Label']
#
# ../analytics/02-21-2018-analytics.parquet
# ...
